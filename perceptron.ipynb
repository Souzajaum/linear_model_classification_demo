# %%
from numpy.random.mtrand import randint
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
import numpy as np
import random
np.random.seed(85)

X, Y = make_classification( n_features=2, n_redundant=0, n_informative=1, n_clusters_per_class=1 )




def plotModel(w1, w2, b):

  plt.scatter(X[:, 0], X[:, 1], marker='o', c=Y, edgecolor='k')

  x = np.linspace(-2, 4, 50)
  y = (-w1*x -b)/w2

  xmin, xmax = plt.gca().get_xlim()
  ymin, ymax = plt.gca().get_ylim()

  plt.axvline(0, -1, 1, color='k', linewidth=1)
  plt.axhline(0, -2, 4, color='k', linewidth=1)
  plt.plot(x, y)
  plt.grid(True)

  plt.xlim(xmin, xmax)
  plt.ylim(ymin, ymax)


w1 = -5
w2 = 0.7
b  = 0.1

plotModel(w1, w2, b)

p = [random.uniform(-2.0, 2.9), random.uniform(-2.0, 2.9)]
print("Distance from the line:", w1* p[0] + w2 * p[1] + b)


def classify(point, w1, w2, b):
  ret = w1 * point[0] + w2 * point[1] + b
  
  if(ret >= 0):
    return 0, 'blue'
  else:
    return 1, 'yellow'

classe, color = classify(p, w1, w2, b)
print("Classification: ", classe, color)

plotModel(w1, w2, b)
plt.scatter(p[0], p[1], marker='x', color='r' )

hits = 0
for k in range(len(X)):
  category, _ = classify(X[k], w1, w2, b)
  if category == Y[k]:
    hits += 1

print("Hits: ", hits)
print("Accuracy: {0}%".format((hits/len(X)*100)))
# Out:
# Distance from the line: -5.712419962637515
# Classification:  1 yellow
# Hits:  92
# Accuracy: 92.0%
